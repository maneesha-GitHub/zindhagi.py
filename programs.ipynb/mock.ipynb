# %%
#mock test
class Student:
    college_name="Pyspyders"
    college_code="A1-123"
    stream="Ece"
    student_count=0
    stu_details={}
    college_info={}
    
    
    def __init__(self,stu_name,phone,email,address,mark1,mark2,mark3):
        self.stu_name=stu_name
        self.phone=phone
        self.email=email
        self.address=address
        self.mark1=mark1
        self.mark2=mark2
        self.mark3=mark3
        self.stu_count_inc(self)
        self.studend_id=100+self.student_count
        self.setStudDetails(self.studend_id,self)

    @classmethod
    def stu_count_inc(cls,self):
        self.student_count+=1
    
    @classmethod
    def setStudDetails(cls,id,self):
        cls.stu_details[id]=self

    def student_info(self):
        n=int(input("choose the option: \n0.calculateTotal\n1.displayStudentDetails\n2.displaySpecificStudent\n3.ModifyMarks\n4.changePhoneNo\n5.Exit"))
        print("-"*150)
        match n:
            case 0:
                self.calculateTotal()
            case 1:
                self.displayStudDetails()
            case 2:
                self.Display_specific_student()
            case 3:
                self.Modify_marks()
            case 4:
                self.change_phn_no()
            case _:
                return
        return self.student_info()    
        

    def calculateTotal(self):
        total=self.mark1+self.mark2+self.mark3
        print(total)
        percentage=(total/100)*300
        return percentage
    #calculateTotal()

    def displayStudDetails(self):
       # print(f"stu_name: {self.stu_name}")
        #print(f"phone: {self.phone}")
        #print(f"email: {self.email}")
        #print(f"address: {self.address}")
        #print(f"mark1 : {self.mark1}")
        #print(f"mark2 : {self.mark2}")
        #print(f"mark3 : {self.mark3}")
    #displayStudDetails()
        
        total_marks = self.calculate_total()
        percentage = total_marks / 3
        print(f"Roll No: {self.roll_no}, Name: {self.stud_name}, Total Marks: {total_marks}, Percentage: {percentage}%")


    def Display_specific_student(self):
        print(f"roll.no: {self.student_id}")
        print(f"total: {self.calculateTotal}")
    #Display_specific_student()
        
    def Modify_marks(self):
        new_mark1=int(input("Enter the new mark1"))
        self.mark1=new_mark1
        new_mark2=int(input("Enter the new mark12"))
        self.mark2=new_mark2
        new_mark3=int(input("Enter the new mark3"))
        self.mark3=new_mark3
    #Modify_marks()

    def change_phn_no(self):
        new_phone=int(input("Enter the new phone"))
        self.phone=new_phone

    #change_phn_no()



    
    
    
    #self.displayStudDetails()

Student1=Student("dora",8723654789,"dora@gmail.com","nellore",90,97,78)
print(Student1.__dict__)
Student2=Student ( "dora",8723654789,"dora@gmail.com","nellore",93,47,73)
print(Student1.__dict__)
Student3=Student("dora",8723654789,"dora@gmail.com","nellore",94,67,98)
print(Student1.__dict__)
Student4=Student("dora",8723654789,"dora@gmail.com","nellore",80,77,58)
print(Student1.__dict__)


Student1.displayStudDetails()
Student2.displayStudDetails()
Student3.displayStudDetails()
Student4.displayStudDetails()


Student1.student_info()
Student2.student_info()
Student3.student_info()
Student4.student_info()
# Out:
# {'stu_name': 'dora', 'phone': 8723654789, 'email': 'dora@gmail.com', 'address': 'nellore', 'mark1': 90, 'mark2': 97, 'mark3': 78, 'student_count': 1, 'studend_id': 101}
# {'stu_name': 'dora', 'phone': 8723654789, 'email': 'dora@gmail.com', 'address': 'nellore', 'mark1': 90, 'mark2': 97, 'mark3': 78, 'student_count': 1, 'studend_id': 101}
# {'stu_name': 'dora', 'phone': 8723654789, 'email': 'dora@gmail.com', 'address': 'nellore', 'mark1': 90, 'mark2': 97, 'mark3': 78, 'student_count': 1, 'studend_id': 101}
# {'stu_name': 'dora', 'phone': 8723654789, 'email': 'dora@gmail.com', 'address': 'nellore', 'mark1': 90, 'mark2': 97, 'mark3': 78, 'student_count': 1, 'studend_id': 101}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Murali\Desktop\zindhagi.py\programs.ipynb\mock.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/mock.ipynb#W3sZmlsZQ%3D%3D?line=104'>105</a> Student4=Student("dora",8723654789,"dora@gmail.com","nellore",80,77,58)
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/mock.ipynb#W3sZmlsZQ%3D%3D?line=105'>106</a> print(Student1.__dict__)
# --> <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/mock.ipynb#W3sZmlsZQ%3D%3D?line=108'>109</a> Student1.displayStudDetails()
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/mock.ipynb#W3sZmlsZQ%3D%3D?line=109'>110</a> Student2.displayStudDetails()
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/mock.ipynb#W3sZmlsZQ%3D%3D?line=110'>111</a> Student3.displayStudDetails()
#
# c:\Users\Murali\Desktop\zindhagi.py\programs.ipynb\mock.ipynb Cell 1 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/mock.ipynb#W3sZmlsZQ%3D%3D?line=56'>57</a> def displayStudDetails(self):
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/mock.ipynb#W3sZmlsZQ%3D%3D?line=57'>58</a>    # print(f"stu_name: {self.stu_name}")
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/mock.ipynb#W3sZmlsZQ%3D%3D?line=58'>59</a>     #print(f"phone: {self.phone}")
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/mock.ipynb#W3sZmlsZQ%3D%3D?line=63'>64</a>     #print(f"mark3 : {self.mark3}")
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/mock.ipynb#W3sZmlsZQ%3D%3D?line=64'>65</a> #displayStudDetails()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/mock.ipynb#W3sZmlsZQ%3D%3D?line=66'>67</a>     total_marks = self.calculate_total()
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/mock.ipynb#W3sZmlsZQ%3D%3D?line=67'>68</a>     percentage = total_marks / 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/mock.ipynb#W3sZmlsZQ%3D%3D?line=68'>69</a>     print(f"Roll No: {self.roll_no}, Name: {self.stud_name}, Total Marks: {total_marks}, Percentage: {percentage}%")
#
# AttributeError: 'Student' object has no attribute 'calculate_total'

# %%
#mock test
class Student:
    college_name="Pyspyders"
    college_code="A1-123"
    stream="Ece"
    student_count=0
    stu_details={}
    college_info={}
    
    
    def __init__(self,stu_name,phone,email,address,mark1,mark2,mark3):
        self.stu_name=stu_name
        self.phone=phone
        self.email=email
        self.address=address
        self.mark1=mark1
        self.mark2=mark2
        self.mark3=mark3
        self.stu_count_inc(self)
        self.student_id=100+self.student_count
        self.setStudDetails(self.student_id,self)

    @classmethod
    def stu_count_inc(cls,self):
        self.student_count+=1
    
    @classmethod
    def setStudDetails(cls,id,obj):
        cls.stu_details[id]=obj

    def student_info(self):
        n=int(input("choose the option: \n0.calculateTotal\n1.displayStudentDetails\n2.displaySpecificStudent\n3.ModifyMarks\n4.changePhoneNo\n5.Exit"))
        print("-"*150)
        match n:
            case 0:
                self.calculateTotal()
            case 1:
                self.displayStudDetails()
            case 2:
                self.Display_specific_student()
            case 3:
                self.Modify_marks()
            case 4:
                self.change_phn_no()
            case _:
                return
        return self.student_info()    
        

    def calculateTotal(self):
        total=self.mark1+self.mark2+self.mark3
        print(total)
        percentage=(total/100)*300
        return percentage
    #calculateTotal()

    def displayStudDetails(self):
       # print(f"stu_name: {self.stu_name}")
        #print(f"phone: {self.phone}")
        #print(f"email: {self.email}")
        #print(f"address: {self.address}")
        #print(f"mark1 : {self.mark1}")
        #print(f"mark2 : {self.mark2}")
        #print(f"mark3 : {self.mark3}")
    #displayStudDetails()
        
        total_marks = self.calculateTotal()
        percentage = total_marks / 3
        print(f"student Id: {self.student_id}, Name: {self.stu_name}, Total Marks: {total_marks}, Percentage: {percentage}%")


    def Display_specific_student(self):
        print(f"Student id: {self.student_id}")
        print(f"total: {self.calculateTotal}")
    #Display_specific_student()
        
    def Modify_marks(self):
        new_mark1=int(input("Enter the new mark1"))
        self.mark1=new_mark1
        new_mark2=int(input("Enter the new mark12"))
        self.mark2=new_mark2
        new_mark3=int(input("Enter the new mark3"))
        self.mark3=new_mark3
    #Modify_marks()

    def change_phn_no(self):
        new_phone=int(input("Enter the new phone"))
        self.phone=new_phone

    #change_phn_no()



    
    
    
    #self.displayStudDetails()

Student1=Student("dora",8723654789,"dora@gmail.com","nellore",90,97,78)
print(Student1.__dict__)
Student2=Student ( "dora",8723654789,"dora@gmail.com","nellore",93,47,73)
print(Student1.__dict__)
Student3=Student("dora",8723654789,"dora@gmail.com","nellore",94,67,98)
print(Student1.__dict__)
Student4=Student("dora",8723654789,"dora@gmail.com","nellore",80,77,58)
print(Student1.__dict__)


Student1.displayStudDetails()
Student2.displayStudDetails()
Student3.displayStudDetails()
Student4.displayStudDetails()


Student1.student_info()
Student2.student_info()
Student3.student_info()
Student4.student_info()
# Out:
# {'stu_name': 'dora', 'phone': 8723654789, 'email': 'dora@gmail.com', 'address': 'nellore', 'mark1': 90, 'mark2': 97, 'mark3': 78, 'student_count': 1, 'student_id': 101}
# {'stu_name': 'dora', 'phone': 8723654789, 'email': 'dora@gmail.com', 'address': 'nellore', 'mark1': 90, 'mark2': 97, 'mark3': 78, 'student_count': 1, 'student_id': 101}
# {'stu_name': 'dora', 'phone': 8723654789, 'email': 'dora@gmail.com', 'address': 'nellore', 'mark1': 90, 'mark2': 97, 'mark3': 78, 'student_count': 1, 'student_id': 101}
# {'stu_name': 'dora', 'phone': 8723654789, 'email': 'dora@gmail.com', 'address': 'nellore', 'mark1': 90, 'mark2': 97, 'mark3': 78, 'student_count': 1, 'student_id': 101}
# 265
# student Id: 101, Name: dora, Total Marks: 795.0, Percentage: 265.0%
# 213
# student Id: 101, Name: dora, Total Marks: 639.0, Percentage: 213.0%
# 259
# student Id: 101, Name: dora, Total Marks: 777.0, Percentage: 259.0%
# 215
# student Id: 101, Name: dora, Total Marks: 645.0, Percentage: 215.0%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 265
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#committed
class Student:
    college_name = "Pyspyders"
    college_code = "A1-123"
    stream = "Ece"
    student_count = 0
    stu_details = {}
    college_info = {}

    def __init__(self, stu_name, phone, email, address, mark1, mark2, mark3):
        self.stu_name = stu_name
        self.phone = phone
        self.email = email
        self.address = address
        self.mark1 = mark1
        self.mark2 = mark2
        self.mark3 = mark3
        Student.stu_count_inc()
        self.student_id = 100 + Student.student_count
        self.setStudDetails(self.student_id, self)

    @classmethod
    def stu_count_inc(cls):
        cls.student_count += 1

    @classmethod
    def setStudDetails(cls, id, obj):
        cls.stu_details[id] = obj

    def student_info(self):
        n = int(input(
            "Choose the option:\n0. Calculate Total\n1. Display Student Details\n2. Display Specific Student\n3. Modify Marks\n4. Change Phone No\n5. Exit"))
        print("-" * 150)
        match n:
            case 0:
                self.calculate_total()
            case 1:
                self.display_stud_details()
            case 2:
                self.display_specific_student()
            case 3:
                self.modify_marks()
            case 4:
                self.change_phn_no()
            case _:
                return
        return self.student_info()

    def calculate_total(self):
        total = self.mark1 + self.mark2 + self.mark3
        print(total)
        percentage = (total / 100) * 300
        return percentage

    def display_stud_details(self):
        total_marks = self.calculate_total()
        percentage = total_marks / 3
        print(f"Student ID: {self.student_id}, Name: {self.stu_name}, Total Marks: {total_marks}, Percentage: {percentage}%")

    def display_specific_student(self):
        print(f"Student ID: {self.student_id}")
        print(f"Total: {self.calculate_total()}")

    def modify_marks(self):
        new_mark1 = int(input("Enter the new mark1: "))
        self.mark1 = new_mark1
        new_mark2 = int(input("Enter the new mark2: "))
        self.mark2 = new_mark2
        new_mark3 = int(input("Enter the new mark3: "))
        self.mark3 = new_mark3


    def change_phn_no(self):
        new_phone = int(input("Enter the new phone: "))
        self.phone = new_phone


Student1 = Student("Dora", 8723654789, "dora@gmail.com", "Nellore", 90, 97, 78)
print(Student1.__dict__)
Student2 = Student("Dora", 8723654789, "dora@gmail.com", "Nellore", 93, 47, 73)
print(Student2.__dict__)
Student3 = Student("Dora", 8723654789, "dora@gmail.com", "Nellore", 94, 67, 98)
print(Student3.__dict__)
Student4 = Student("Dora", 8723654789, "dora@gmail.com", "Nellore", 80, 77, 58)
print(Student4.__dict__)

Student1.display_stud_details()
Student2.display_stud_details()
Student3.display_stud_details()
Student4.display_stud_details()

Student1.student_info()
Student2.student_info()
Student3.student_info()
Student4.student_info()
# Out:
# {'stu_name': 'Dora', 'phone': 8723654789, 'email': 'dora@gmail.com', 'address': 'Nellore', 'mark1': 90, 'mark2': 97, 'mark3': 78, 'student_id': 101}
# {'stu_name': 'Dora', 'phone': 8723654789, 'email': 'dora@gmail.com', 'address': 'Nellore', 'mark1': 93, 'mark2': 47, 'mark3': 73, 'student_id': 102}
# {'stu_name': 'Dora', 'phone': 8723654789, 'email': 'dora@gmail.com', 'address': 'Nellore', 'mark1': 94, 'mark2': 67, 'mark3': 98, 'student_id': 103}
# {'stu_name': 'Dora', 'phone': 8723654789, 'email': 'dora@gmail.com', 'address': 'Nellore', 'mark1': 80, 'mark2': 77, 'mark3': 58, 'student_id': 104}
# 265
# Student ID: 101, Name: Dora, Total Marks: 795.0, Percentage: 265.0%
# 213
# Student ID: 102, Name: Dora, Total Marks: 639.0, Percentage: 213.0%
# 259
# Student ID: 103, Name: Dora, Total Marks: 777.0, Percentage: 259.0%
# 215
# Student ID: 104, Name: Dora, Total Marks: 645.0, Percentage: 215.0%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 265
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 265
# Student ID: 101, Name: Dora, Total Marks: 795.0, Percentage: 265.0%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Student ID: 101
# 265
# Total: 795.0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
