# %%
class Hotel_Z1:
    hname="Luv_u_foodie"
    branch="Nellore"
    food="veg","non-veg","desserts"
    gst=19
    cart=[]
    account_details={}
    def __init__(self,name,phone,email):
        self.name=name
        self.phone=phone
        self.email=email
        self.concat_acc_details(self,self.email)
   
    #@classmethod
    def concat_acc_details(cls,email,obj):
        cls.account_details[email]=obj
    def lets_begin(self):
        n=int(input("choose the option: \n0.login\n1.menu\n2orders\n3.cart\n4.Exit"))
        print("*"*150)
        match n:
            case 0:
                self.login()
            case 1:
                self.menu()
            case 2:
                self.order()
            case 3:
                self.cart_list()
            case _:
                return
        self.lets_begin()
    def menu(self):
        def veg():
            print("Vegetarian Menu:")
            print("1. Gobi Manchurian - 70")
            print("2. Veg Manchurian - 60")
            print("3. Paneer Tikka - 100")
            print("4. Baby Corn Manchurian - 120")
            print("5. Veg Biryani - 200")
            print("6. Paneer Biryani - 220")
            print("7. Mushroom Biryani - 260")

        def non_veg():
            print("Non-Vegetarian Menu:")
            print("1. Chicken 65 - 90")
            print("2. Chicken Lollipop - 120")
            print("3. Chicken Tikka - 150")
            print("4. Keema Samosa - 200")
            print("5. Chicken Biryani - 300")
            print("6. Mutton Biryani - 360")
            print("7. Fish Fried Biryani - 350")

        def desserts():
            print("Desserts Menu:")
            print("1. Baked Desserts - 60")
            print("2. Frozen Desserts - 150")
            print("3. Dessert Drinks - 90")
            print("4. Cold Desserts - 120")
            print("5. Fried Desserts - 100")
            print("6. Puddings - 90")
            print("7. Cobblers - 80")
        veg()
        non_veg()
        desserts()
    def order(self):
        n=int(input("choose the option: \n0.vegetarian menu\n1.non-vegetarian\n2.desserts\n3.Exit"))
        print("-"*150)
        match n:
            case 0:
                m=int(input("choose the option: \n0.Vegetarian Menu\n1.Gobi manchurian\n2.veg manchurian\n3.paneer Tikka\n4.Baby corn Manchurian\n5.veg biriyani\n6.paneer biriyani\n7.mushroom biriyani \n8.Exit"))
                print("*"*150)
                match m:
                    case 0:
                        self.veg()
                    case 1:
                        self.cart_list("Gobi manchurian",70)
                    case 2:
                        self.cart_list("veg manchurian" ,60)
                    case 3:
                       self.cart_list("paneer Tikka",100)
                    case 4:
                       self.cart_list("Baby corn Manchurian",120)
                    case 5:
                      self.cart_list("veg biriyani",200)
                    case 6:
                        self.cart_list("paneer biriyani",220)
                    case 7:
                        self.cart_list("mushroom biriyani ",260)
                    case _:
                        return
            case 1:
                o=int(input("choose the option: \n0.Non Vegetarian Menu\n1.chicken 65\n2. chicken lolipop\n3.chicken tikka\n4.keema samosa\n5.chicken biriyani\n6.mutton biriyani\n7.fish fried biriyani \n8.Exit"))
                print("*"*150)
                match o:
                    case 0:
                        self.non_veg()
                    case 1:
                       self.cart_list("Non Vegetarian Menu",90)
                    case 2:
                        self.cart_list("chicken 65",120)
                    case 3:
                        self.cart_list("chicken lolipop",150)
                    case 4:
                        self.cart_list("chicken tikka",200)
                    case 5:
                       self.cart_list("keema samosa",300)
                    case 6:
                       self.cart_list("chicken biriyani",360)
                    case 7:
                        self.cart_list("mutton biriyani",350)
                    case 8:
                        self.cart_list("fish fried biriyani",350)
                    case _:
                        return
            case 2:
                p=int(input("choose the option: \n0.desserts menu\n1.Baked Desserts\n2.frozen Dessert\n3.Dessert Drinks\n4.Cold Desserts\n5.Fried Desserts\n6.puddings\n7.Custards\n8.Exit"))
                print("*"*150)
                match p:
                    case 0:
                        self.desserts()
                    case 1:
                      self.cart_list("Baked Desserts",60)
                    case 2:
                       self.cart_list("frozen Dessert",150)
                    case 3:
                     self.cart_list("Dessert Drinks",90)
                    case 4:
                       self.cart_list("Cold Desserts",120)
                    case 5:
                        self.cart_list("Fried Desserts",100)
                    case 6:
                        self.cart_list("puddings",90)
                    case 7:
                       self.cart_list("Custards",80)
                       
                    case _:
                        return
    def cart_list(self, item, price):
        quantity = int(input(f"Enter quantity for {item}: "))
        self.cart.append({"item": item, "price": price, "quantity": quantity})
        print(f"{quantity} {item} added to cart.")

    #def display_cart(self):
        if not self.cart:
            print("Your cart is empty.")
        else:
            print("Your Cart:")
            for item in self.cart:
                print(f"{item['quantity']} * {item['item']} - rs{item['price']* item['quantity']} ")
    
    #@classmethod
    def login(cls):
        login_id=input("Enter the email id:")
        password=int(input("Enter the phn num:"))
        if login_id in cls.account_details and cls.account_details[login_id].phone == password:
            self = cls.account_details[login_id]
            cls.lets_begin(self)
        #print(self.email)
        else:
            print("Invalid login id or password")
    login(Hotel_Z1)
        
        
obj=Hotel_Z1("doremon",123,"dora")
obj1=Hotel_Z1("sinchan",9123007895,"sinchan@gmail.com")

print(obj.__dict__)
print(obj1.__dict__)
obj.lets_begin()
obj.order()
# Out:
# Invalid login id or password
# {'name': 'doremon', 'phone': 123, 'email': 'dora'}
# {'name': 'sinchan', 'phone': 9123007895, 'email': 'sinchan@gmail.com'}
# ******************************************************************************************************************************************************
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#with recursion
class Hotel_Z1:
    hname="Luv_u_foodie"
    branch="Nellore"
    food="veg","non-veg","desserts"
    gst=19
    cart=[]
    account_details={}
    def __init__(self,name,phone,email):
        self.name=name
        self.phone=phone
        self.email=email
        self.concat_acc_details(self.email,self)
   
    #@classmethod
    #def concat_cust_details(cls,acc_no,obj):
     #   cls.cust_details[acc_no]=obj
    @classmethod
    def concat_acc_details(cls,email,obj):
        cls.account_details[email]=obj
    def lets_begin(self):
        n=int(input("choose the option: \n0.login\n1.menu\n2orders\n3.cart\n4.bill\n5.Exit"))
        print("*"*150)
        match n:
            case 0:
                self.login()
            case 1:
                self.menu()
            case 2:
                self.order()
            case 3:
                self.cart_list()
            case 4:
                self.bill()
            case _:
                return
        
    def menu(self):
        def veg():
            print("Vegetarian Menu:")
            print("1. Gobi Manchurian - 70")
            print("2. Veg Manchurian - 60")
            print("3. Paneer Tikka - 100")
            print("4. Baby Corn Manchurian - 120")
            print("5. Veg Biryani - 200")
            print("6. Paneer Biryani - 220")
            print("7. Mushroom Biryani - 260")

        def non_veg():
            print("Non-Vegetarian Menu:")
            print("1. Chicken 65 - 90")
            print("2. Chicken Lollipop - 120")
            print("3. Chicken Tikka - 150")
            print("4. Keema Samosa - 200")
            print("5. Chicken Biryani - 300")
            print("6. Mutton Biryani - 360")
            print("7. Fish Fried Biryani - 350")

        def desserts():
            print("Desserts Menu:")
            print("1. Baked Desserts - 60")
            print("2. Frozen Desserts - 150")
            print("3. Dessert Drinks - 90")
            print("4. Cold Desserts - 120")
            print("5. Fried Desserts - 100")
            print("6. Puddings - 90")
            print("7. Cobblers - 80")
        veg()
        non_veg()
        desserts()
    def order(self):
        n=int(input("choose the option: \n0.vegetarian menu\n1.non-vegetarian\n2.desserts\n3.Exit"))
        print("-"*150)
        match n:
            case 0:
                m=int(input("choose the option: \n0.Vegetarian Menu\n1.Gobi manchurian\n2.veg manchurian\n3.paneer Tikka\n4.Baby corn Manchurian\n5.veg biriyani\n6.paneer biriyani\n7.mushroom biriyani \n8.Exit"))
                print("*"*150)
                match m:
                    case 0:
                        self.veg()
                    case 1:
                        self.cart_list("Gobi manchurian",70)
                    case 2:
                        self.cart_list("veg manchurian" ,60)
                    case 3:
                       self.cart_list("paneer Tikka",100)
                    case 4:
                       self.cart_list("Baby corn Manchurian",120)
                    case 5:
                      self.cart_list("veg biriyani",200)
                    case 6:
                        self.cart_list("paneer biriyani",220)
                    case 7:
                        self.cart_list("mushroom biriyani ",260)
                    case _:
                        return 
            case 1:
                o=int(input("choose the option: \n0.Non Vegetarian Menu\n1.chicken 65\n2. chicken lolipop\n3.chicken tikka\n4.keema samosa\n5.chicken biriyani\n6.mutton biriyani\n7.fish fried biriyani \n8.Exit"))
                print("*"*150)
                match o:
                    case 0:
                        self.non_veg()
                    case 1:
                       self.cart_list("Non Vegetarian Menu",90)
                    case 2:
                        self.cart_list("chicken 65",120)
                    case 3:
                        self.cart_list("chicken lolipop",150)
                    case 4:
                        self.cart_list("chicken tikka",200)
                    case 5:
                       self.cart_list("keema samosa",300)
                    case 6:
                       self.cart_list("chicken biriyani",360)
                    case 7:
                        self.cart_list("mutton biriyani",350)
                    case 8:
                        self.cart_list("fish fried biriyani",350)
                    case _:
                        return
            case 2:
                p=int(input("choose the option: \n0.desserts menu\n1.Baked Desserts\n2.frozen Dessert\n3.Dessert Drinks\n4.Cold Desserts\n5.Fried Desserts\n6.puddings\n7.Custards\n8.Exit"))
                print("*"*150)
                match p:
                    case 0:
                        self.desserts()
                    case 1:
                      self.cart_list("Baked Desserts",60)
                    case 2:
                       self.cart_list("frozen Dessert",150)
                    case 3:
                     self.cart_list("Dessert Drinks",90)
                    case 4:
                       self.cart_list("Cold Desserts",120)
                    case 5:
                        self.cart_list("Fried Desserts",100)
                    case 6:
                        self.cart_list("puddings",90)
                    case 7:
                       self.cart_list("Custards",80)
                       
                    case _:
                        return
    def cart_list(self, item, price):
        quantity = int(input(f"Enter quantity for {item}: "))
        self.cart.append({"item": item, "price": price, "quantity": quantity})
        #for item in self.cart:
        print(f"{quantity} {item} added to cart.")

    #def bill():
        if not self.cart:
            print("Your cart is empty.")
        else:
            print("Your Cart:")
            for item in self.cart:
                print(f"{item['quantity']} * {item['item']} - ${item['price']* item['quantity']} ")
    
                
    
    def login(cls):
        login_id=input("Enter the email id:")
        password=int(input("Enter the phn num:"))
        if login_id in cls.account_details and cls.account_details[login_id].phone == password:
            self = cls.account_details[login_id]
            cls.lets_begin(self)
        #print(self.email)
        else:
            print("Invalid login id or password")
    login(Hotel_Z1)
        
        
obj=Hotel_Z1("doremon",8712316628,"doremon@gmail.com")
obj1=Hotel_Z1("sinchan",9123007895,"sinchan@gmail.com")
print(obj.__dict__)
print(obj1.__dict__)
obj.lets_begin()
obj.order()
#obj.bill()
obj.login()
# Out:
# Invalid login id or password
# {'name': 'doremon', 'phone': 8712316628, 'email': 'doremon@gmail.com'}
# {'name': 'sinchan', 'phone': 9123007895, 'email': 'sinchan@gmail.com'}
# ******************************************************************************************************************************************************
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Murali\Desktop\zindhagi.py\programs.ipynb\zomatoproject.ipynb Cell 3 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W2sZmlsZQ%3D%3D?line=176'>177</a> obj.order()
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W2sZmlsZQ%3D%3D?line=177'>178</a> #obj.bill()
# --> <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W2sZmlsZQ%3D%3D?line=178'>179</a> obj.login()
#
# c:\Users\Murali\Desktop\zindhagi.py\programs.ipynb\zomatoproject.ipynb Cell 3 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W2sZmlsZQ%3D%3D?line=162'>163</a> if login_id in cls.account_details and cls.account_details[login_id].phone == password:
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W2sZmlsZQ%3D%3D?line=163'>164</a>     self = cls.account_details[login_id]
# --> <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W2sZmlsZQ%3D%3D?line=164'>165</a>     cls.lets_begin(self)
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W2sZmlsZQ%3D%3D?line=165'>166</a> #print(self.email)
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W2sZmlsZQ%3D%3D?line=166'>167</a> else:
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W2sZmlsZQ%3D%3D?line=167'>168</a>     print("Invalid login id or password")
#
# TypeError: Hotel_Z1.lets_begin() takes 1 positional argument but 2 were given

# %%
class Hotel_Z1:
    hname="Luv_u_foodie"
    branch="Nellore"
    food="veg","non-veg","desserts"
    gst=19
    cart=[]
    account_details={}
    def __init__(self,name,phone,email):
        self.name=name
        self.phone=phone
        self.email=email
        self.concat_acc_details(self.email,self)
   
    #@classmethod
    #def concat_cust_details(cls,acc_no,obj):
     #   cls.cust_details[acc_no]=obj
    @classmethod
    def concat_acc_details(cls,email,obj):
        cls.account_details[email]=obj
    def lets_begin(self):
        n=int(input("choose the option: \n0.login\n1.menu\n2orders\n3.cart\n4.bill\n5.Exit"))
        print("*"*150)
        match n:
            case 0:
                self.login()
            case 1:
                self.menu()
            case 2:
                self.order()
            case 3:
                self.cart_list()
            case 4:
                self.bill()
            case _:
                return
        self.lets_begin()
        
    def menu(self):
        def veg():
            print("Vegetarian Menu:")
            print("1. Gobi Manchurian - 70")
            print("2. Veg Manchurian - 60")
            print("3. Paneer Tikka - 100")
            print("4. Baby Corn Manchurian - 120")
            print("5. Veg Biryani - 200")
            print("6. Paneer Biryani - 220")
            print("7. Mushroom Biryani - 260")

        def non_veg():
            print("Non-Vegetarian Menu:")
            print("1. Chicken 65 - 90")
            print("2. Chicken Lollipop - 120")
            print("3. Chicken Tikka - 150")
            print("4. Keema Samosa - 200")
            print("5. Chicken Biryani - 300")
            print("6. Mutton Biryani - 360")
            print("7. Fish Fried Biryani - 350")

        def desserts():
            print("Desserts Menu:")
            print("1. Baked Desserts - 60")
            print("2. Frozen Desserts - 150")
            print("3. Dessert Drinks - 90")
            print("4. Cold Desserts - 120")
            print("5. Fried Desserts - 100")
            print("6. Puddings - 90")
            print("7. Cobblers - 80")
        veg()
        non_veg()
        desserts()
    def order(self):
        n=int(input("choose the option: \n0.vegetarian menu\n1.non-vegetarian\n2.desserts\n3.Exit"))
        print("-"*150)
        match n:
            case 0:
                m=int(input("choose the option: \n0.Vegetarian Menu\n1.Gobi manchurian\n2.veg manchurian\n3.paneer Tikka\n4.Baby corn Manchurian\n5.veg biriyani\n6.paneer biriyani\n7.mushroom biriyani \n8.Exit"))
                print("*"*150)
                match m:
                    case 0:
                        self.veg()
                    case 1:
                        self.cart_list("Gobi manchurian",70)
                    case 2:
                        self.cart_list("veg manchurian" ,60)
                    case 3:
                       self.cart_list("paneer Tikka",100)
                    case 4:
                       self.cart_list("Baby corn Manchurian",120)
                    case 5:
                      self.cart_list("veg biriyani",200)
                    case 6:
                        self.cart_list("paneer biriyani",220)
                    case 7:
                        self.cart_list("mushroom biriyani ",260)
                    case _:
                        return
            case 1:
                o=int(input("choose the option: \n0.Non Vegetarian Menu\n1.chicken 65\n2. chicken lolipop\n3.chicken tikka\n4.keema samosa\n5.chicken biriyani\n6.mutton biriyani\n7.fish fried biriyani \n8.Exit"))
                print("*"*150)
                match o:
                    case 0:
                        self.non_veg()
                    case 1:
                       self.cart_list("Non Vegetarian Menu",90)
                    case 2:
                        self.cart_list("chicken 65",120)
                    case 3:
                        self.cart_list("chicken lolipop",150)
                    case 4:
                        self.cart_list("chicken tikka",200)
                    case 5:
                       self.cart_list("keema samosa",300)
                    case 6:
                       self.cart_list("chicken biriyani",360)
                    case 7:
                        self.cart_list("mutton biriyani",350)
                    case 8:
                        self.cart_list("fish fried biriyani",350)
                    case _:
                        return
            case 2:
                p=int(input("choose the option: \n0.desserts menu\n1.Baked Desserts\n2.frozen Dessert\n3.Dessert Drinks\n4.Cold Desserts\n5.Fried Desserts\n6.puddings\n7.Custards\n8.Exit"))
                print("*"*150)
                match p:
                    case 0:
                        self.desserts()
                    case 1:
                      self.cart_list("Baked Desserts",60)
                    case 2:
                       self.cart_list("frozen Dessert",150)
                    case 3:
                     self.cart_list("Dessert Drinks",90)
                    case 4:
                       self.cart_list("Cold Desserts",120)
                    case 5:
                        self.cart_list("Fried Desserts",100)
                    case 6:
                        self.cart_list("puddings",90)
                    case 7:
                       self.cart_list("Custards",80)
                       
                    case _:
                        return
            case _:
                return
        self.order()
    
    def cart_list(self, item, price):
        quantity = int(input(f"Enter quantity for {item}: "))
        self.cart.append({"item": item, "price": price, "quantity": quantity})
        print(f"{quantity} {item} added to cart.")
        if not self.cart:
            print("Your cart is empty.")
        else:
            print("Your Cart:")
            for item in self.cart:
                print(f"{item['quantity']} * {item['item']} - rs{item['price']* item['quantity']}")
    def bill(self):
        total_amt=0
        if not self.cart:
            print("Your Cart is Empty. Bill Not Generated")
            return
        else:
            print("Your Bill")
            print("-------------------------------------------------------")
            print("Item\t\t\t Quantity\t\t Price")
            print("-------------------------------------------------------")
            gst=20
            for item in self.cart:
                item_name=item['item']
                quantity=item['quantity']
                price=item['price']
                item_total=quantity*price+gst
                print(f"{item_name}\t\t\t{quantity}\t\t\tRs{item_total}")
                print("--------------------------------------------------------")
                print(f"Total Amount: Rs{item_total}")
                print("-------------------------------------------------------")
                print("Thank You For Ordering Enjoy the Food!")
    
    
    
    def login(self):
        login_id=input("Enter the email id:")
        password=int(input("Enter the phn num:"))
        if login_id in self.account_details and self.account_details[login_id].phone == password:
            #self = cls.account_details[login_id]
            print("login successfull" )
            self.lets_begin()
        #print(self.email)
        else:
            print("Invalid login id or password")
        
        
obj=Hotel_Z1("doremon",8712316628,"doremon@gmail.com")
obj1=Hotel_Z1("sinchan",9123007895,"sinchan@gmail.com")
print(obj.__dict__)
print(obj1.__dict__)
obj.lets_begin()
#obj.order()
# Out:
# {'name': 'doremon', 'phone': 8712316628, 'email': 'doremon@gmail.com'}
# {'name': 'sinchan', 'phone': 9123007895, 'email': 'sinchan@gmail.com'}
# ******************************************************************************************************************************************************
# Your Cart is Empty. Bill Not Generated
# ******************************************************************************************************************************************************
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Murali\Desktop\zindhagi.py\programs.ipynb\zomatoproject.ipynb Cell 4 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W3sZmlsZQ%3D%3D?line=195'>196</a> print(obj.__dict__)
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W3sZmlsZQ%3D%3D?line=196'>197</a> print(obj1.__dict__)
# --> <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W3sZmlsZQ%3D%3D?line=197'>198</a> obj.lets_begin()
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W3sZmlsZQ%3D%3D?line=198'>199</a> #obj.order()
#
# c:\Users\Murali\Desktop\zindhagi.py\programs.ipynb\zomatoproject.ipynb Cell 4 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W3sZmlsZQ%3D%3D?line=33'>34</a>     case _:
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W3sZmlsZQ%3D%3D?line=34'>35</a>         return
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W3sZmlsZQ%3D%3D?line=35'>36</a> self.lets_begin()
#
# c:\Users\Murali\Desktop\zindhagi.py\programs.ipynb\zomatoproject.ipynb Cell 4 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W3sZmlsZQ%3D%3D?line=28'>29</a>     self.order()
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W3sZmlsZQ%3D%3D?line=29'>30</a> case 3:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W3sZmlsZQ%3D%3D?line=30'>31</a>     self.cart_list()
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W3sZmlsZQ%3D%3D?line=31'>32</a> case 4:
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W3sZmlsZQ%3D%3D?line=32'>33</a>     self.bill()
#
# TypeError: Hotel_Z1.cart_list() missing 2 required positional arguments: 'item' and 'price'

# %%
class Hotel:
    Hotel_Name="Welcome Foodie"
    Branch="Hyderabad"
    Food="Tiffins","Veg Starters","Veg Main Course"
    GST=20
    cart=[]
    account_details={}
    def __init__(self,name,phone,email,password):
        self.name=name
        self.phone=phone
        self.email=email
        self.password=password
        self.concat_acc_details(self.email,self)
   
    #@classmethod
    #def concat_cust_details(cls,acc_no,obj):
     #   cls.cust_details[acc_no]=obj
    @classmethod
    def concat_acc_details(self,email,obj):
        self.account_details[email]=obj
    def Order_Now(self):
        n=int(input("choose the option: \n0.Login\n1.Menu\n2.Orders\n3.Cart\n4.Bill\n5.Exit"))
        print("-"*150)
        match n:
            case 0:
                self.Login()
            case 1:
                self.menu()
            case 2:
                self.order()
            case 3:
                self.cart_list()
            case 4:
                self.generate_bill()
            case _:
                return
        return self.Order_Now()    
        
    def menu(self):
        def Tiffins():
            print("Tiffins")
            print("1.Plain Dosa + sambar and coconut chutney, Rs50")
            print("2.Masala Dosa + sambar and coconut chutney, Rs90")
            print("3.Butter Dosa + sambar and coconut chutney, Rs70")
            print("4.Plain Idly + sambar and coconut chutney, Rs40")
            print("5.Butter Idly + sambar and coconut chutney, Rs50")
            print("6.Mysore Dosa + sambar and coconut chutney, Rs100")
            print("7.Upma, Rs 30")
            print("8.Mysore Bonda+ sambar and coconut chutney, Rs80")
            print("9.Vada + sambar and coconut chutney, Rs70")
            
        def Veg_Starters():
            print("Veg Starters:")
            print("1.Veg Manchurain(Dry), 90")
            print("2.Veg Gravy Manchurain, Rs 160")
            print("3.Gobi Manchurain(Dry), Rs 150")
            print("4.Spring Rolls, Rs 110")
            print("5.Baby Corn Manchurian, Rs 120")
            print("6.Paneer Tikka(Dry), Rs 110")
            print("7.Spicy Cheese Balls, Rs 150")
            
        def Veg_MainCourse():
            print("Veg Main Course")
            print("1.Plain Roti, Rs20")
            print("2.Butter Naan, R40")
            print("3.Kadhai Paneer, Rs120")
            print("4.Paneer Butter Masala,170")
            print("5.Masala Kofta, Rs130")
            print("6.Malai Kofta, Rs170")  
            print("7.Handi Biryani, Rs220") 
            print("8.Paneer Biryani, Rs240") 
            print("9.Mushroom Biryani, Rs220")
            
        Tiffins()
        Veg_Starters()
        Veg_MainCourse()
    def order(self):
        n=int(input("choose the option: \n0.Tiffins\n1.Veg Starters\n2.Main Course\n3.Exit"))
        print("-"*150)
        match n:
            case 0:
                m=int(input("choose the option: \n0.Tiffins\n1.Plain Dosa + sambar and coconut chutney\n2.Masala Dosa + sambar and coconut chutney\n3.Butter Dosa + sambar and coconut chutney\n4.Plain Idly + sambar and coconut chutney\n5.Butter Idly + sambar and coconut chutney\n6.Mysore Dosa + sambar and coconut chutney\n7.Upma \n8.Mysore Bonda+ sambar and coconut chutney\n9.Vada + sambar and coconut chutney\n10.Exit"))
                print("-"*150)
                match m:
                    case 0:
                        self.Tiffins()
                    case 1:
                        self.cart_list("Palin Dosa+sambar and coconut chutney",50)
                    case 2:
                        self.cart_list("Masala Dosa + sambar and coconut chutney" ,90)
                    case 3:
                       self.cart_list("Butter Dosa + sambar and coconut chutney",70)
                    case 4:
                       self.cart_list("Plain Idly + sambar and coconut chutney",40)
                    case 5:
                      self.cart_list("Butter Idly + sambar and coconut chutney",50)
                    case 6:
                        self.cart_list("Mysore Dosa + sambar and coconut chutney",100)
                    case 7:
                        self.cart_list("Upma",260)
                    case 8:
                        self.cart_list("Mysore Bonda+ sambar and coconut chutney",80)
                    case 9:
                        self.cart_list("Vada + sambar and coconut chutney",70)
                    case _:
                        return
            case 1:
                p=int(input("choose the option: \n0.Starters\n1.Veg Manchurain(Dry)\n2.Veg Gravy Manchurain\n3.Gobi Manchurain(Dry)\n4.Spring Rolls\n5.Baby Corn Manchurian\n6.Paneer Tikka(Dry)\n7.Spicy Cheese Balls\n8.Exit"))
                print("-"*150)
                match p:
                    case 0:
                        self.Veg_Starters()
                    case 1:
                       self.cart_list("Veg Manchurian(Dry)",90)
                    case 2:
                        self.cart_list("Veg Gravy Manchurian",160)
                    case 3:
                        self.cart_list("Gobi Manchurian(Dry)",150)
                    case 4:
                        self.cart_list("Spring Rolls",110)
                    case 5:
                       self.cart_list("Baby Corr Manchurian",120)
                    case 6:
                       self.cart_list("Paneer Tikka",110)
                    case 7:
                        self.cart_list("Spicy Cheese Balls",150)
                    case _:
                        return
            case 2:
                p=int(input("choose the option: \n0.Veg_Main Course\n1.Plain Roti\n2.Butter Naan\n3.Kadhai Paneer\n4.Paneer Butter Masala\n5.Masala Kofta\n6.Malai Kofta\n7.Handi Biryani\n8.Paneer Biryani\n9.Mushroom Biryani\n10.Exit"))
                print("*"*150)
                match p:
                    case 0:
                        self.Veg_MainCourse()
                    case 1:
                      self.cart_list("Plain Roti",20)
                    case 2:
                       self.cart_list("Butter Naan",40)
                    case 3:
                     self.cart_list("Kadhai Paneer",120)
                    case 4:
                       self.cart_list("Paneer Butter Masala",170)
                    case 5:
                        self.cart_list("Masala Kofta",130)
                    case 6:
                        self.cart_list("Malai Kofta",170)
                    case 7:
                       self.cart_list("Handi Biryani",2200)
                    case 8:
                       self.cart_list("Paneer Biryani",240)
                    case 9:
                       self.cart_list("Mushroom Biryani",220)
                    case _:
                        return
    def cart_list(self, item, price):
        quantity = int(input(f"Enter quantity for {item}: "))
        self.cart.append({"item": item, "price": price, "quantity": quantity})
        print(f"{quantity} {item} added to cart.")

    #def display_cart(self):
        if not self.cart:
            print("Your cart is empty.")
        else:
            print("Your Cart:")
            for item in self.cart:
                print(f"{item['quantity']} x {item['item']} - Rs{item['price']* item['quantity']}")
              
    
    def generate_bill(self):
        total_amt=0
        if not self.cart:
            print("Your Cart is Empty. Bill Not Generated")
            return
        else:
            print("Your Bill")
            print("-------------------------------------------------------")
            print("Item\t\t\t Quantity\t\t Price")
            print("-------------------------------------------------------")
            gst=20
            for item in self.cart:
                item_name=item['item']
                quantity=item['quantity']
                price=item['price']
                item_total=quantity*price+gst
                print(f"{item_name}\t\t\t{quantity}\t\t\tRs{item_total}")
                print("--------------------------------------------------------")
                print(f"Total Amount: Rs{item_total}")
                print("-------------------------------------------------------")
                print("Thank You For Ordering Enjoy the Food!")

    def Login(self):
        login_id=input("Enter the email id:")
        password=int(input("Enter the password"))
        if login_id in self.account_details and self.account_details[login_id].password == password:
            #self = cls.account_details[login_id]
            self.Order_Now()
        #print(self.email)
        else:
            print("Invalid login id or password")  

        
        
obj=Hotel("tanvi",8712316628,"tanvi@gmail.com",1234)
obj1=Hotel("Manu",9123007895,"Manu@gmail.com",5678)
print(obj.__dict__)
print(obj1.__dict__)
obj.Order_Now()
#obj.menu()
obj.order()
# Out:
# {'name': 'tanvi', 'phone': 8712316628, 'email': 'tanvi@gmail.com', 'password': 1234}
# {'name': 'Manu', 'phone': 9123007895, 'email': 'Manu@gmail.com', 'password': 5678}
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Tiffins
# 1.Plain Dosa + sambar and coconut chutney, Rs50
# 2.Masala Dosa + sambar and coconut chutney, Rs90
# 3.Butter Dosa + sambar and coconut chutney, Rs70
# 4.Plain Idly + sambar and coconut chutney, Rs40
# 5.Butter Idly + sambar and coconut chutney, Rs50
# 6.Mysore Dosa + sambar and coconut chutney, Rs100
# 7.Upma, Rs 30
# 8.Mysore Bonda+ sambar and coconut chutney, Rs80
# 9.Vada + sambar and coconut chutney, Rs70
# Veg Starters:
# 1.Veg Manchurain(Dry), 90
# 2.Veg Gravy Manchurain, Rs 160
# 3.Gobi Manchurain(Dry), Rs 150
# 4.Spring Rolls, Rs 110
# 5.Baby Corn Manchurian, Rs 120
# 6.Paneer Tikka(Dry), Rs 110
# 7.Spicy Cheese Balls, Rs 150
# Veg Main Course
# 1.Plain Roti, Rs20
# 2.Butter Naan, R40
# 3.Kadhai Paneer, Rs120
# 4.Paneer Butter Masala,170
# 5.Masala Kofta, Rs130
# 6.Malai Kofta, Rs170
# 7.Handi Biryani, Rs220
# 8.Paneer Biryani, Rs240
# 9.Mushroom Biryani, Rs220
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Murali\Desktop\zindhagi.py\programs.ipynb\zomatoproject.ipynb Cell 5 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=204'>205</a> print(obj.__dict__)
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=205'>206</a> print(obj1.__dict__)
# --> <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=206'>207</a> obj.Order_Now()
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=207'>208</a> #obj.menu()
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=208'>209</a> obj.order()
#
# c:\Users\Murali\Desktop\zindhagi.py\programs.ipynb\zomatoproject.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=23'>24</a> match n:
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=24'>25</a>     case 0:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=25'>26</a>         self.Login()
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=26'>27</a>     case 1:
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=27'>28</a>         self.menu()
#
# c:\Users\Murali\Desktop\zindhagi.py\programs.ipynb\zomatoproject.ipynb Cell 5 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=192'>193</a> password=int(input("Enter the password"))
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=193'>194</a> if login_id in self.account_details and self.account_details[login_id].password == password:
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=194'>195</a>     #self = cls.account_details[login_id]
# --> <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=195'>196</a>     self.Order_Now()
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=196'>197</a> #print(self.email)
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=197'>198</a> else:
#     <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=198'>199</a>     print("Invalid login id or password")
#
# c:\Users\Murali\Desktop\zindhagi.py\programs.ipynb\zomatoproject.ipynb Cell 5 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=34'>35</a>     case _:
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=35'>36</a>         return
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=36'>37</a> return self.Order_Now()
#
# c:\Users\Murali\Desktop\zindhagi.py\programs.ipynb\zomatoproject.ipynb Cell 5 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=29'>30</a>     self.order()
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=30'>31</a> case 3:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=31'>32</a>     self.cart_list()
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=32'>33</a> case 4:
#      <a href='vscode-notebook-cell:/c%3A/Users/Murali/Desktop/zindhagi.py/programs.ipynb/zomatoproject.ipynb#W4sZmlsZQ%3D%3D?line=33'>34</a>     self.generate_bill()
#
# TypeError: Hotel.cart_list() missing 2 required positional arguments: 'item' and 'price'
